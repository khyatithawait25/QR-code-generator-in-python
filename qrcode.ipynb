# %%
import qrcode as qr
img=qr.make("www.linkedin.com/in/khyati-thawait-0a9852218")
img.save("D:/python/khayti_linkdin.png")

# %% [markdown]
# In this we can generate any url link to Qrcode
# using qrcode and its make and save function
